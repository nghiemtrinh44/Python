# %%
# bài 1
thang = int(input("nhap thang: "))
nam = int(input("nhap nam: "))
if thang < 1 or thang > 12 :
    print(" khng hop le ")
elif thang in [1, 3, 5, 7, 8, 10, 12]:
    print("31 ngay")
elif thang in [4, 6, 9, 11]:
    print("30 ngay ")

else :
    if(nam % 400 ==0) or (nam %4 & nam %100 !=0):
        print("29")
    else:
        print("28")
# Out:
# 31 ngay

# %%
# bài 2
ngay = int(input(" nhập ngày sinh "))
thang = int(input(" nhập tháng sinh: "))
if thang > 12 or thang < 1:
    print (" ngày hoặc tháng không hợp lệ ")
else:
    if thang in [1, 3, 5, 7, 8, 10, 12]:
        print("số ngày = 31")
    elif thang in [4, 6, 9, 11]:
        print("số ngày = 30")
    else:

        print ("số ngày = 28")
if ngay > 31 or ngay < 1:
    print (" không hợp lệ ")
else:
    if (thang == 3 and ngay >= 21) or (thang == 4 and ngay <= 19):
        print("Bạch Dương")
    elif (thang == 4 and ngay >= 20) or (thang == 5 and ngay <= 20):
        print("Kim Ngưu")
    elif (thang == 5 and ngay >= 21) or (thang == 6 and ngay <= 20):
        print("Song Tử")
    elif (thang == 6 and ngay >= 21) or (thang == 7 and ngay <= 22):
        print("Cự Giải")
    elif (thang == 7 and ngay >= 23) or (thang == 8 and ngay <= 22):
        print("Sư Tử")
    elif (thang == 8 and ngay >= 23) or (thang == 9 and ngay <= 22):
        print("Xử Nữ")
    elif (thang == 9 and ngay >= 23) or (thang == 10 and ngay <= 22):
        print("Thiên Bình")
    elif (thang == 10 and ngay >= 23) or (thang == 11 and ngay <= 21):
        print("Bọ Cạp")
    elif (thang == 11 and ngay >= 22) or (thang == 12 and ngay <= 21):
        print("Nhân Mã")
    elif (thang == 12 and ngay >= 22) or (thang == 1 and ngay <= 19):
        print("Ma Kết")
    elif (thang == 1 and ngay >= 20) or (thang == 2 and ngay <= 18):
        print("Bảo Bình")
    else:
        print("Song Ngư")
# Out:
# số ngày = 31
# Song Ngư

# %%
# bài 3
n = int(input("nhập n: "))
tu=abs(n)
if tu == 0:
    so_chu_so = 1
    tong = 0
else:
    so_chu_so =0
    tong = 0
    while tu >0:
        tong += tu % 10
        so_chu_so += 1
        tu //=10
if n < 2:
    la_so_nguyen_to = False
else:
    la_so_nguyen_to = True
    i =2
    while i*i <= n:
        if n %2==0:
            la_so_nguyen_to = False
            break
        i+=1
print ("Số chữ số:", so_chu_so)
print ("Tổng chữ số:", tong)
if la_so_nguyen_to:
    print(n, " là số nguyên tố")
else:
    print(n, " không là số nguyên tố")
# Out:
# Số chữ số: 3
# Tổng chữ số: 8
# 134  không là số nguyên tố

# %%
#bài 4
N = int(input("Nhập số tiền (xu): "))
gia = 28
mua = N // gia
tong = mua
vo = mua
doi = 0
while vo >= 3:
    chai_doi = vo // 3
    doi += chai_doi
    tong += chai_doi
    vo = vo % 3 + chai_doi
print("Số chai bia có thể mua được là: {}".format(tong))
print("(Mua {} chai ban đầu, đổi thêm {} chai, còn {} vỏ.)".format(mua, doi, vo))
# Out:
# Số chai bia có thể mua được là: 13
# (Mua 9 chai ban đầu, đổi thêm 4 chai, còn 1 vỏ.)
